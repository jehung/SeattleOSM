# %% [markdown]
# # Cleaning and Wrangling: Seattle Open Street Map

# %% [markdown]
# We now analyze Open Street Map for the City of Seattle.

# %% [markdown]
# ## Explore a Subset of Data

# %% [markdown]
# Due to the size of the dataset, we need a way to systematically slice the original dataset for a workable sample to explore. To this end, I have used the following code to achieve this. The **k** value is changed from large to small so that my resulting
# *SAMPLE_FILE* ends up at different sizes. When starting out, try using a larger k, then move on to an intermediate k before processing your whole dataset.

# %%
import xml.etree.ElementTree as ET  # Use cElementTree or lxml if too slow
import xml.etree.cElementTree as ET
import pprint
import pickle
from collections import defaultdict
import re

# %%
OSM_FILE = "seattle_washington.osm"  # Replace this with your osm file
SAMPLE_FILE = "test.osm"

k = 5000 # Parameter: take every k-th top level element

def get_element(osm_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag

    Reference:
    http://stackoverflow.com/questions/3095434/inserting-newlines-in-xml-file-generated-via-xml-etree-elementtree-in-python
    """
    context = iter(ET.iterparse(osm_file, events=('start', 'end')))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()


with open(SAMPLE_FILE, 'wb') as output:
    output.write('<?xml version="1.0" encoding="UTF-8"?>\n'.encode('utf-8'))
    output.write('<osm>\n  '.encode('utf-8'))

    # Write every kth top level element
    for i, element in enumerate(get_element(OSM_FILE)):
        if i % k == 0:
            output.write(ET.tostring(element, encoding='utf-8'))

    output.write('</osm>'.encode('utf-8'))

# %%
output.close()

# %% [markdown]
# At the end of the above code, we end up with a file *test.osm* with which we can use to explore the dataset.

# %% [markdown]
# ### Develop a Dictionary for All Tags In the Original Dataset

# %% [markdown]
# Our goal here is to end up with a Python dictionary for the tags in the original dataset, so that we know what needs to be wrangled in the data. The following achives this.

# %%
def count_tags(filename):
    tags = {}
    
    for event, elem in ET.iterparse(filename):
        if elem.tag not in tags:
            tags[elem.tag] = 1
            if 
        else:
            tags[elem.tag] += 1
    
    return tags

# %%
tags = count_tags('seattle_washington.osm')

# %%
import pickle 

with open('tags.pickle', 'wb') as tagsPickle:
    pickle.dump(tags, tagsPickle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
with open('tags.pickle', 'rb') as tagsPickle:
    unserialized_tags = pickle.load(tagsPickle)

# %%
unserialized_tags
# Out:
# {'bounds': 1,
#  'member': 88068,
#  'nd': 8453162,
#  'node': 7580046,
#  'osm': 1,
#  'relation': 9411,
#  'tag': 4708553,
#  'way': 750242}

# %% [markdown]
# ### Exploring What Is Contained Within Each Tag Type

# %% [markdown]
# To get a better sense of what sort of attributes is contained inside each type of tag, we use the following code to return this information to us.

# %%
bounds_subtags = []
member_subtags = []
nd_subtags = []
node_subtags = []
osm_subtags = []
relation_subtags = []
tag_subtags = []
way_subtags = []

for _, element in ET.iterparse('seattle_washington.osm'):
    if element.tag == 'bounds' and element.attrib.keys() not in bounds_subtags:
        bounds_subtags.append(element.attrib.keys())
    elif element.tag == 'member' and element.attrib.keys() not in member_subtags:
        member_subtags.append(element.attrib.keys())
    elif element.tag == 'nd' and element.attrib.keys() not in nd_subtags:
        nd_subtags.append(element.attrib.keys())
    elif element.tag == 'node' and element.attrib.keys() not in node_subtags:
        node_subtags.append(element.attrib.keys())
    elif element.tag == 'osm' and element.attrib.keys() not in osm_subtags:
        osm_subtags.append(element.attrib.keys())
    elif element.tag == 'relation' and element.attrib.keys() not in relation_subtags:
        relation_subtags.append(element.attrib.keys())
    elif element.tag == 'tag' and element.attrib.keys() not in tag_subtags:
        tag_subtags.append(element.attrib.keys())
    elif element.tag == 'way' and element.attrib.keys() not in way_subtags:
        way_subtags.append(element.attrib.keys())
    else:
        pass

# %%
bounds_subtags
# Out:
# [dict_keys(['maxlon', 'maxlat', 'minlat', 'minlon'])]

# %%
member_subtags
# Out:
# [dict_keys(['type', 'ref', 'role'])]

# %%
nd_subtags
# Out:
# [dict_keys(['ref'])]

# %%
node_subtags
# Out:
# [dict_keys(['lon', 'version', 'changeset', 'lat', 'timestamp', 'id', 'uid', 'user']),
#  dict_keys(['lon', 'version', 'changeset', 'lat', 'timestamp', 'id'])]

# %%
osm_subtags
# Out:
# [dict_keys(['generator', 'version', 'timestamp'])]

# %%
relation_subtags
# Out:
# [dict_keys(['version', 'changeset', 'timestamp', 'id', 'uid', 'user'])]

# %%
way_subtags
# Out:
# [dict_keys(['version', 'changeset', 'timestamp', 'id', 'uid', 'user'])]

# %%
tag_subtags
# Out:
# [dict_keys(['v', 'k'])]

# %% [markdown]
# ### Audit Plan: Addresses

# %% [markdown]
# From a visual inspection of the subset of Seattle OSM, we get the sense that **<tag>** contains address information. In particular, tags with attribute of  **k** of **addr:street** contains street names that tend to be described inconsistently in the dataset. Therefore, our next goal is to develop a data audit plan that works specifically on tags with addresses.
#
# The following chuncks of code achive this goal.

# %%
street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)


expected = ["Street", "Avenue", "Boulevard", "Drive", "Court", "Place", "Square", "Lane", "Road", 
            "Trail", "Parkway", "Commons"]

# %%
def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")

# %%
def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)

# %%
def audit(osmfile):
    osm_file = open('seattle_washington.osm', 'r', encoding='cp1252', errors='replace')
    street_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=('start',)):
        if elem.tag == 'node' or elem.tag == 'way':
            for tag in elem.iter('tag'):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])
    osm_file.close()
    return street_types

# %%
def update_name(name, mapping):
    m = street_type_re.search(name)
    street_type = m.group()
    
    name = re.sub(street_type, mapping[street_type], name)
    return name

# %%
st_types = audit(OSM_FILE)

# %%
st_types
# Out:
# defaultdict(set,
#             {'1': {'228th St SE Suite 1', 'Southeast 132nd Street #1'},
#              '100': {'Northwest Byron Street #100',
#               'Old Highway 9 Southwest  #100',
#               'S 196th St #100',
#               'Southeast 38th Street Suite 100'},
#              '101': {'156th Street East #101',
#               '5th Street #101',
#               'East Highway 101',
#               'East US Highway 101'},
#              '102': {'15th Street Southwest  #102'},
#              '104': {'Northeast State Highway 104', 'State Highway 104'},
#              '105': {'State Route 105'},
#              '110': {'Northeast 4th Street, Suite 110'},
#              '1109': {'NE Northgate Way #1109'},
#              '112': {'Craftsman Way Suite 112'},
#              '11th': {'South 11th'},
#              '12': {'HWY 12', 'State Route 12', 'US Highway 12'},
#              '125': {'Better Way SE Ste 125'},
#              '12th': {'South 12th'},
#              '13th': {'South 13th'},
#              '140': {'Highlands Dr NE Ste 140'},
#              '149': {'East Madison Street, Suite 149'},
#              '14th': {'North 14th'},
#              '15th': {'North 15th', 'South 15th'},
#              '16': {'West State Highway 16'},
#              '16th': {'North 16th', 'South 16th'},
#              '17th': {'North 17th'},
#              '183': {'Lake City Way Northeast #183'},
#              '18th': {'North 18th', 'South 18th'},
#              '19th': {'19th', 'North 19th'},
#              '1st': {'North 1st', 'South 1st'},
#              '2': {'Highway 2', 'US 2'},
#              '20': {'State Route 20', 'West State Route 20'},
#              '200': {'4th Ave W, Suite 200'},
#              '207': {'West Republican Street Apt 207'},
#              '20th': {'South 20th'},
#              '210': {'224th St E # 210'},
#              '214': {'224th St E # 214'},
#              '23rd': {'North 23rd'},
#              '25th': {'South 25th'},
#              '27th': {'South 27th'},
#              '2nd': {'South 2nd'},
#              '3': {'Northeast State Route 3'},
#              '305': {'State Highway 305'},
#              '308': {'Hwy 308', 'Northeast State Highway 308'},
#              '30th': {'North 30th', 'South 30th'},
#              '32nd': {'North 32nd'},
#              '410': {'Highway 410', 'State Route 410'},
#              '4114': {'4114'},
#              '44th': {'SE 44th'},
#              '4th': {'North 4th'},
#              '525': {'State Route 525'},
#              '530': {'E BURKE AVE/SR 530'},
#              '536': {'State Highway 536', 'State Route 536'},
#              '65th': {'NE 65th'},
#              '6th': {'North 6th', 'South 6th'},
#              '7807)': {'Bellevue Square (7807)'},
#              '79': {'Northeast 12th Street, Ste 79'},
#              '8th': {'North 8th'},
#              '9': {'State Highway 9', 'State Route 9'},
#              '906': {'SR 906', 'State Route 906'},
#              '92': {'State Route 92'},
#              '98103': {'3401 Evanston Ave N, Suite A Seattle WA, 98103'},
#              '98296': {'196th Street Southeast, Snohomish, WA 98296'},
#              '99': {'Highway 99', 'State Highway 99'},
#              'A': {'124th Avenue Northeast  #A',
#               '184th Street East Suite A',
#               'Avenue A',
#               'Old Highway 99 Southwest # A'},
#              'AVENUE': {'EASTERN AVENUE'},
#              'Acres': {'Hollydale Acres'},
#              'Alley': {'Braeburn Alley',
#               'Fan Tan Alley',
#               'Geneva Alley',
#               'Post Alley',
#               'Scotland Alley',
#               "Scott's Alley",
#               "Seth's Alley",
#               "Skyler's Alley",
#               "Steve's Alley",
#               'Stone Haven Alley',
#               'Trounce Alley',
#               'Zylstra Alley'},
#              'Apache': {'Apache'},
#              'Av.': {'Pacific Av.'},
#              'Ave': {'14th Ave',
#               '18870 SW 103rd Ave',
#               '18th Ave',
#               '1st Ave',
#               '22nd Ave',
#               '2nd Ave',
#               '34th Ave',
#               '3rd Ave',
#               '4th Ave',
#               '5th Ave',
#               '6th Ave',
#               'Boylston Ave',
#               'Division Ave',
#               'East Main Ave',
#               'Fawcett Ave',
#               'Meridian East Ave',
#               'Rucker Ave',
#               'South 2nd Ave',
#               'South Sheridan Ave',
#               'Union Ave'},
#              'Ave.': {'East Yelm Ave.', 'Simpson Ave.'},
#              'B': {'60th Lane Southeast unit B',
#               'Colby Ave B',
#               'Hoyt Road Southwest B'},
#              'Bend': {'Cherry Tree Bend', 'Wild Berry Bend'},
#              'Berniece': {'East Berniece'},
#              'Blackburn': {'East Blackburn', 'West Blackburn'},
#              'Blvd': {'Alderwood Mall Blvd',
#               'Mill Creek Blvd',
#               'NE Gilman Blvd',
#               'NW Gilman Blvd',
#               'Northeast Sunset Blvd',
#               'Regents Blvd',
#               'Sargent Blvd'},
#              'Blvd.': {'NW Gilman Blvd.', 'Northwest Gilman Blvd.'},
#              'Box': {'PO Box'},
#              'Broad': {'Broad'},
#              'Broadway': {'Broadway',
#               'East Broadway',
#               'N Broadway',
#               'North Broadway'},
#              'Burwell': {'Burwell'},
#              'C': {'228th Street SE  Suite C'},
#              'CT': {'SE 10TH CT'},
#              'Center': {'Parkplace Center'},
#              'Central': {'Central'},
#              'Chase': {'Steeple Chase'},
#              'Circle': {'Briarwood Circle',
#               'Bridlewood Circle',
#               'Commerce Circle',
#               'Foxglove Circle',
#               'Heather Circle',
#               'Hunts Point Circle',
#               'Kirkland Circle',
#               'Lam Circle',
#               'Mamich Circle',
#               'Montana Circle',
#               'North Greenwood Circle',
#               'Northeast 37th Circle',
#               'Northeast 81st Circle',
#               'Northwest Roundhill Circle',
#               'Ohde Circle',
#               'Rosewood Circle',
#               'West Lawton Circle',
#               'hunts point Circle'},
#              'Cleveland': {'Cleveland', 'South Cleveland'},
#              'Close': {'Academy Close',
#               'Atherly Close',
#               'Bellamy Close',
#               'Bessborough Close',
#               'Braefoot Close',
#               'Buckingham Close',
#               'Burnley Close',
#               'Cartmel Close',
#               'Cedarwood Close',
#               'Chimo Close',
#               'Cottontree Close',
#               'Crestmont Close',
#               'Crosshaven Close',
#               'Cyril Close',
#               'Elise Close',
#               'Emerald Close',
#               'Epsom Close',
#               'Firbank Close',
#               'Hermes Close',
#               'Hibbens Close',
#               'Knockan Close',
#               'La Fontaine Close',
#               'Livingstone Close',
#               'Maltwood Close',
#               'Medberry Close',
#               'Mocha Close',
#               'Morningside Close',
#               'Normandy Close',
#               'Oakview Close',
#               'Palamos Close',
#               'Palmer Close',
#               'Perimeter Close',
#               'Persimmon Close',
#               'Quailwood Close',
#               'Race Passage Close',
#               'Rockhampton Close',
#               'Rogers Close',
#               'San Miguel Close',
#               'Scottswood Close',
#               'Spirit Close',
#               "St. Peter's Close",
#               'Stoneridge Close',
#               'Sunkist Close',
#               'Tasco Close',
#               'Thelma Close',
#               'Wessex Close',
#               'Western Slope Close',
#               'Wynwood Close'},
#              'Cove': {'Mills Cove'},
#              'Crescent': {'Alamida Crescent',
#               'Alpine Crescent',
#               'Antrobus Crescent',
#               'Beam Crescent',
#               'Bellbarbie Crescent',
#               'Brighton Crescent',
#               'Brodick Crescent',
#               'Burbank Crescent',
#               'Burleith Crescent',
#               'Campus Crescent',
#               'Camrose Crescent',
#               'Carnegie Crescent',
#               'Casa Marcia Crescent',
#               'Charmar Crescent',
#               'Cherrilee Crescent',
#               'Colwood Crescent',
#               'Cressida Crescent',
#               'Crossandra Crescent',
#               'Crown Crescent',
#               'Cuaulta Crescent',
#               'Dawnview Crescent',
#               'Denford Crescent',
#               'Dunbar Crescent',
#               'Dunnett Crescent',
#               'Eastridge Crescent',
#               'Egerton Crescent',
#               'Elnido Crescent',
#               'Enterprise Crescent',
#               'Falaise Crescent',
#               'Galiano Crescent',
#               'Ganges Crescent',
#               'Gault Crescent',
#               'Gosper Crescent',
#               'Granada Crescent',
#               'Greenridge Crescent',
#               'Helvetia Crescent',
#               'Hess Crescent',
#               'Hibberson Crescent',
#               'Hollywood Crescent',
#               'Hoylake Crescent',
#               'Joan Crescent',
#               'Jolivet Crescent',
#               'Karen Crescent',
#               'Kellett Crescent',
#               'Kingsberry Crescent',
#               'Kona Crescent',
#               'Lascelles Crescent',
#               'Lochwood Crescent',
#               'Lynnfield Crescent',
#               'Mallek Crescent',
#               'Martha Crescent',
#               'Mary Anne Crescent',
#               'Memorial Crescent',
#               'Meredith Crescent',
#               'Moody Crescent',
#               'Murdoch Crescent',
#               'NE Cedar Park Crescent',
#               'Narvaez Crescent',
#               'Newstead Crescent',
#               'Northridge Crescent',
#               'Oakfield Crescent',
#               'Oakridge Crescent',
#               'Orange Blossom Crescent',
#               'Orelebar Crescent',
#               'Parkside Crescent',
#               'Pearce Crescent',
#               'Pepin Crescent',
#               'Polyanthus Crescent',
#               'Powliuk Crescent',
#               'Promenade Crescent',
#               'Rainbow Crescent',
#               'Ridgebank Crescent',
#               'Ridgewood Crescent',
#               'Robleda Crescent',
#               'Rolston Crescent',
#               'Rowils Crescent',
#               'Saltair Crescent',
#               'San Marino Crescent',
#               'San Rafael Crescent',
#               'Springridge Crescent',
#               'Stockton Crescent',
#               'Summerhill Crescent',
#               'Swindell Crescent',
#               'Tanglewood Crescent',
#               'Thetis Crescent',
#               'Thetis Vale Crescent',
#               'Thornhill Crescent',
#               'Tibbitt Crescent',
#               'Tovey Crescent',
#               'Trafalgar Crescent',
#               'Tribune Crescent',
#               'Triest Crescent',
#               'Vantilburg Crescent',
#               'Verona Crescent',
#               'Virago Crescent',
#               'Waterfront Crescent',
#               'Wellesley Crescent',
#               'Wellsmith Crescent',
#               'Wessex Crescent',
#               'Wildview Crescent',
#               'Winston Crescent',
#               'Woodlawn Crescent',
#               'Wootton Crescent',
#               'Zealous Crescent'},
#              'Ct': {'NE 108th Ct', 'NE 30th Ct'},
#              'D': {'Avenue D', 'Northeast 20th Street Suite D'},
#              'Dakota': {'Dakota'},
#              'Dell': {'Dingley Dell'},
#              'Departures': {'SeaTac Departures'},
#              'Division': {'East Division', 'West Division'},
#              'Douglas': {'Douglas'},
#              'Dr': {'Harbour Reach Dr', 'SE Swenson Dr', 'W Marine View Dr'},
#              'Dr.': {'SE May Creek Park Dr.'},
#              'E': {'10th Ave E',
#               '12th Ave E',
#               '20th Ave E',
#               '20th Street E',
#               '54th Avenue E',
#               '72nd Street E',
#               'Canyon Rd E',
#               'Canyon Road E',
#               'Court E',
#               'Delmar Dr E',
#               'East Madison Street #E',
#               'Fairview Ave E',
#               'Lake Tapps Parkway E',
#               'Lower Burnett Rd E',
#               'Martin Way E',
#               'Meridian Avenue E',
#               'Mountain Hwy E',
#               'Pacific Highway E',
#               'Pioneer Way E',
#               'Portland Avenue E',
#               'SR 410 E',
#               'State Route 410 E'},
#              'E.': {'Quinnon Rd. Ext. E.'},
#              'E.Division': {'E.Division'},
#              'East': {'10th Avenue East',
#               '110th Avenue East',
#               '112th Street East',
#               '119th Avenue East',
#               '11th Avenue East',
#               '122nd Avenue East',
#               '127th Avenue Court East',
#               '128th Street East',
#               '12th Avenue East',
#               '136th Street East',
#               '13th Avenue East',
#               '140th Avenue East',
#               '144th Street East',
#               '14th Avenue East',
#               '152nd Street East',
#               '15th Avenue East',
#               '166th Avenue East',
#               '168th Street East',
#               '16th Avenue East',
#               '176th Street East',
#               '17th Avenue East',
#               '180 Avenue Court East',
#               '181 Avenue Court East',
#               '182 Avenue Court East',
#               '184th Street East',
#               '186th Avenue East',
#               '18th Avenue East',
#               '199th Avenue Court East',
#               '19th Avenue East',
#               '20th Avenue East',
#               '20th Street East',
#               '215th Avenue East',
#               '21st Avenue East',
#               '224th Street East',
#               '22nd Avenue East',
#               '230th Avenue East',
#               '23rd Avenue East',
#               '24th Avenue East',
#               '24th Street East',
#               '25th Avenue East',
#               '26th Avenue East',
#               '27th Avenue East',
#               '28th Avenue East',
#               '29th Avenue East',
#               '30th Avenue East',
#               '31st Avenue East',
#               '32nd Avenue East',
#               '33rd Avenue East',
#               '34th Avenue East',
#               '34th Street East',
#               '35th Avenue East',
#               '36th Avenue East',
#               '37th Avenue East',
#               '37th Place East',
#               '38th Avenue East',
#               '38th Place East',
#               '39th Avenue East',
#               '40th Avenue East',
#               '41st Avenue East',
#               '42nd Avenue East',
#               '437th Street East',
#               '43rd Avenue East',
#               '4th Avenue East',
#               '541st Street East',
#               '542nd Street East',
#               '54th Avenue East',
#               '64th Street East',
#               '72ND Street East',
#               '72nd Street East',
#               '75th Street East',
#               '80th Street East',
#               '86th Avenue East',
#               '94th Avenue East',
#               '98th Street East',
#               'Arboretum Drive East',
#               'Arboretum Place East',
#               'Bellevue Avenue East',
#               'Bellevue Court East',
#               'Bellevue Place East',
#               'Belmont Avenue East',
#               'Belmont Place East',
#               'Blenheim Drive East',
#               'Boyer Avenue East',
#               'Boylston Avenue East',
#               'Broadmoor Drive East',
#               'Broadway Avenue East',
#               'Broadway East',
#               'Bukin Drive East',
#               'Burnside Road East',
#               'Canterbury Lane East',
#               'Canyon Road East',
#               'Center Street East',
#               'Coryell Court East',
#               'Delmar Drive East',
#               'Dewey Place East',
#               'Dorffel Drive East',
#               'Duke Road East',
#               'East Lake Avenue East',
#               'East Montlake Place East',
#               'East Park Drive East',
#               'Eastlake Avenue East',
#               'Everett Avenue East',
#               'Fairview Avenue East',
#               'Federal Avenue East',
#               'Franklin Avenue East',
#               'Franklin Place East',
#               'Fruitland Avenue East',
#               'Fuhrman Avenue East',
#               'Garthland Place East',
#               'Glenwilde Place East',
#               'Gorge Road East',
#               'Grandview Place East',
#               'Grant Road East',
#               'Harvard Avenue East',
#               'Hillside Drive East',
#               'Interlaken Drive East',
#               'Interlaken Place East',
#               'Knox Place East',
#               'Lake Washington Boulevard East',
#               'Lakeview Boulevard East',
#               'Lexington Way East',
#               'Lohbrunner Road East',
#               'MacDonald Drive East',
#               'Maddock Avenue East',
#               'Madrona Place East',
#               'Maiden Lane East',
#               'Main Street East',
#               'Malden Avenue East',
#               'Martin Luther King Junior Way East',
#               'Martin Way East',
#               'McGilvra Boulevard East',
#               'Melrose Avenue East',
#               'Meridian Avenue East',
#               'Milwaukee Avenue East',
#               'Minor Avenue East',
#               'Montgomery Court East',
#               'Montlake Boulevard East',
#               'Mountain Highway East',
#               'Mrtin Way East',
#               'Northeast Day Road East',
#               'Orting-Kapowsin Highway East',
#               'Pacific Highway East',
#               'Parkside Drive East',
#               'Peach Court East',
#               'Portage Bay Place East',
#               'Remond Way East',
#               'Royal Court East',
#               'Shaw Road East',
#               'Shenandoah Drive East',
#               'South Tapps Drive East',
#               'State Route 706 East',
#               'Summit Avenue East',
#               'Treebank Road East',
#               'Turner Way East',
#               'Viaduct Avenue East',
#               'Waller Road East',
#               'Washington Place East',
#               'Waverly Way East',
#               'West Montlake Place East',
#               'West Park Drive East',
#               'Windermere Drive East',
#               'Winslow Way East',
#               'Woodrow Place East',
#               'Yale Avenue East',
#               'Yale Terrace East',
#               'fairview Avenue East'},
#              'Eastwind': {'Eastwind'},
#              'Esplanade': {'Esplanade', 'Northwest Esplanade'},
#              'Estates': {'Sun Estates'},
#              'Everett': {'Hewitt Ave, Everett'},
#              'FI': {'Fox Drive FI'},
#              'FIXME': {'FIXME'},
#              'Fairhaven': {'East Fairhaven'},
#              'Fir': {'East Fir'},
#              'Fowler': {'Fowler'},
#              'Gardens': {'Bluebird Gardens',
#               'Carberry Gardens',
#               'Mayfair Gardens',
#               'Moss Park Gardens',
#               'Piedmont Gardens',
#               'Rockhome Gardens',
#               'Warren Gardens'},
#              'Gate': {'Bishops Gate',
#               'Harrow Gate',
#               'Natures Gate',
#               'Stone Gate'},
#              'Glen': {'Fir Tree Glen'},
#              'Green': {'Harold Green',
#               'Hartford Green',
#               'Knibbs Green',
#               'Leaf Hill Green'},
#              'Grove': {'Sun Grove'},
#              'H': {'Hwy 99, Ste H'},
#              'Harrison': {'Harrison'},
#              'Hazel': {'West Hazel'},
#              'Heights': {'Capital Heights',
#               'Evelyn Heights',
#               'Flury Heights',
#               'James Heights',
#               'Jean Heights',
#               'Lillooet Heights',
#               'Mariposa Heights',
#               'Pueblo Heights',
#               'Queen Anne Heights',
#               'Raven Heights',
#               'Selwyn Heights',
#               'Shorncliffe Heights',
#               'Treetop Heights',
#               'Vista Heights'},
#              'Highway': {'Bothell Everett Highway',
#               'Bothell Evertt Highway',
#               'Bothell Highway',
#               'Bothell-Everett Highway',
#               'East Valley Highway',
#               'Island Highway',
#               'Maple Valley Highway',
#               'Memorial Highway',
#               'National Park Highway',
#               'North Cascades Highway',
#               'Olympic Highway',
#               'Pacific Highway',
#               'Patricia Bay Highway',
#               'Pioneer Highway',
#               'South Skagit Highway',
#               'Stevens Pass Highway',
#               'Trans-Canada Highway',
#               'West Old Cascade Highway'},
#              'Hills': {'Sun Hills'},
#              'Hwy': {'Bothell-Everett Hwy',
#               'East Old Cascade Hwy',
#               'Memorial Hwy'},
#              'Island': {'Elwah View Drive Fox Island'},
#              'Jackson': {'South Jackson'},
#              'Jefferson': {'Jefferson'},
#              'K10': {'NE 8th street, suite K10'},
#              'Kincaid': {'Kincaid'},
#              'Kulshan': {'Kulshan'},
#              'LaVenture': {'North LaVenture'},
#              'Landing': {'Regatta Landing', 'Werra Landing'},
#              'Laventure': {'Laventure', 'North Laventure', 'South Laventure'},
#              'Lawrence': {'West Lawrence'},
#              'Ln.': {'Molly Ln.'},
#              'Loop': {'Alpine Crest Loop',
#               'Barry Loop',
#               'Center SR 104 Loop',
#               'Chestnut Loop',
#               'Coppertop Loop',
#               'Hidden Lake Loop',
#               'Hillcrest Loop',
#               'Lindsay Loop',
#               'Lindsey Loop',
#               'Loch Ness Loop',
#               'Mount Baker Loop',
#               'Nooksack Loop',
#               'Northwest Cherry Loop',
#               'Outrigger Loop',
#               'River Vista Loop',
#               'Silver Loop',
#               'Timberland Loop',
#               'Tundra Loop'},
#              'Lupine': {'Lupine'},
#              'Mall': {'Southcenter Mall'},
#              'Maple': {'Maple'},
#              'Market': {'Market'},
#              'Mccormick': {'Mccormick'},
#              'Mcgarigle': {'Mcgarigle'},
#              'Meadows': {'Les Meadows'},
#              'Meridian': {'North Meridian', 'S Meridian', 'South Meridian'},
#              'Milwaukee': {'Milwaukee'},
#              'Montgomery': {'East Montgomery'},
#              'Murdock': {'Murdock'},
#              'Myrtle': {'Myrtle'},
#              'N': {'Auburn Way N',
#               'Aurora Ave N',
#               'Bagley Ave N',
#               'Bronson Way N',
#               'Greenwood Ave N',
#               'Hwy 99 N',
#               'Keystone Place N',
#               'Park Ave N',
#               'Terry Ave N'},
#              'N.': {'Greenwood Ave N.'},
#              'N.E.': {'40th Ave. N.E.'},
#              'NE': {'104th Ave NE',
#               '105th Avenue NE',
#               '106th Ave NE',
#               '107th Avene NE',
#               '108th Avenue NE',
#               '110th Ave NE',
#               '110th Avenue NE',
#               '111th Ave NE',
#               '111th Avenue NE',
#               '112TH AVE NE',
#               '112th Av NE',
#               '112th Ave NE',
#               '112th Avenue NE',
#               '116th Ave NE',
#               '120th Avenue NE',
#               '124th Avenue NE',
#               '127th PL NE',
#               '132nd Avenue NE',
#               '138th Way NE',
#               '1405 132nd Ave NE',
#               '140th Ave NE',
#               '140th Avenue NE',
#               '141st Ave NE',
#               '148 Ave NE',
#               '148th Ave NE',
#               '148th Avenue NE',
#               '152 Ave NE',
#               '152nd Avenue NE',
#               '155th Place NE',
#               '156th Ave NE',
#               '156th Avenue NE',
#               '156th Pl NE',
#               '156th Place NE',
#               '157th Place NE',
#               '160th Ave NE',
#               '161st Ave NE',
#               '161st Avenue NE',
#               '161th NE',
#               '165TH PL NE',
#               '165th Place NE',
#               '168th Court NE',
#               '170th Place NE',
#               '18006 120TH AVE NE',
#               '180th Pl NE',
#               '182nd Ave NE',
#               '183RD AVE NE',
#               '183rd Pl NE',
#               '185th Ave NE',
#               '186th PL NE',
#               '187th PL NE',
#               '188th Ave NE',
#               '188th LN NE',
#               '208th Avenue NE',
#               '233rd Pl NE',
#               '234th Place NE',
#               '236th Ave NE',
#               '237th Ave NE',
#               '25th Ave NE',
#               '27th Avenue NE',
#               '320th Avenue NE',
#               '35th Avenue NE',
#               '4759 Lynwood Center Rd NE',
#               '84th ST NE',
#               'Adams Street NE',
#               'Bellevue Way NE',
#               'Bothell Way NE',
#               'Brooklyn Ave NE',
#               'Carnation-Duvall Rd NE',
#               'Hogum Bay RD NE',
#               'Juanita Woodinville Way NE',
#               'Main St NE',
#               'Main Street NE',
#               'Marine Dr NE',
#               'Marvin Road NE',
#               'Puget Way NE',
#               'Ravenna Ave NE',
#               'Sand Point Way NE',
#               'Shincke Road NE',
#               'Sleater Kinney Rd NE',
#               'University Way NE',
#               'W Ames Lake Dr NE',
#               'Willamette Dr NE',
#               'Willows Road NE'},
#              'NW': {'12th Ave NW',
#               '13th Ave NW',
#               '14th Ave NW',
#               '17th Ave NW',
#               '18th Ave. NW',
#               '20thAve. NW',
#               '22nd Ave NW',
#               '25th Ave NW',
#               '26th Ave NW',
#               '26th Ave. NW',
#               '271st St NW',
#               '3rd Ave NW',
#               '51st Ave NW',
#               '51st Avenue NW',
#               'Ballard Ave NW',
#               'Columbia ST NW',
#               'Harrison Ave NW',
#               'Harrison Ave. NW',
#               'Harrison Avenue NW',
#               'Kenyon Ave NW',
#               'LAKERIDGE CIR NW',
#               'Limited Ln NW',
#               'Limited lane NW',
#               'Road 65 NW',
#               'Rogers St. NW',
#               'Sunrise Beach Drive NW',
#               'Tallman Ave NW',
#               'West Bay Dr NW'},
#              'North': {'122nd Street North',
#               '17th Place North',
#               '1st Avenue North',
#               '2nd Avenue North',
#               '303 Front Street North',
#               '30th Street North',
#               '34th Place North',
#               '3rd Avenue North',
#               '4th Avenue North',
#               '5th Avenue North',
#               '6th Avenue North',
#               '8th Avenue North',
#               '9th Avenue North',
#               'Albion Place North',
#               'Ashworth Avenue North',
#               'Auburn Way North',
#               'Aurora Avenue North',
#               'Bagley Avenue North',
#               'Ballarat Avenue North',
#               'Beaver Pond Drive North',
#               'Bigelow Avenue North',
#               'Birch Avenue North',
#               'Bitter Place North',
#               'Boren Avenue North',
#               'Bridge Way North',
#               'Burke Avenue North',
#               'Callow Avenue North',
#               'Canfield Place North',
#               'Capitol Way North',
#               'Caroline Avenue North',
#               'Carr Place North',
#               'Central Avenue North',
#               'Chapin Place North',
#               'College Way North',
#               'Corliss Avenue North',
#               'Courtland Place North',
#               'Dayton Avenue North',
#               'Densmore Avenue North',
#               'Dexter Avenue North',
#               'Dexter Way North',
#               'East Green Lake Drive North',
#               'East Green Lake Way North',
#               'Eastern Avenue North',
#               'Evanston Avenue North',
#               'Fairview Avenue North',
#               'Fairview Place North',
#               'Francis Avenue North',
#               'Fremont Avenue North',
#               'Fremont Lane North',
#               'Fremont Place North',
#               'Fremont Way North',
#               'French Road North',
#               'Front Street North',
#               'Galer Place North',
#               'Garden Avenue North',
#               'Green Lake Drive North',
#               'Green Lake Way North',
#               'Greenwood Ave. North',
#               'Greenwood Avenue North',
#               'Holman Road North',
#               'Interlake Avenue North',
#               'Keen Way North',
#               'Kennedy Street North',
#               'Kensington Place North',
#               'Kenwood Place North',
#               'Keystone Place North',
#               'Kirkwood Place North',
#               'Lake Washington Boulevard North',
#               'Lenora Place North',
#               'Linden Avenue North',
#               'Livingstone Avenue North',
#               'Lorentz Place North',
#               'Madison Avenue North',
#               'Madrone Lane North',
#               'Main Street North',
#               'Maple Avenue North',
#               'Mashell Avenue North',
#               'Mayfair Avenue North',
#               'McKinley Place North',
#               'Meridian Avenue North',
#               'Meridian Place North',
#               'Midvale Avenue North',
#               'Minor Avenue North',
#               'Nesbit Avenue North',
#               'Nob Hill Avenue North',
#               'Nob Hill Place North',
#               'North Park Avenue North',
#               'Old 99 North',
#               'Old Highway 99 North',
#               'Old Hwy 99 North',
#               'Orange Place North',
#               'Orin Court North',
#               'Pacific Avenue North',
#               'Palatine Avenue North',
#               'Palatine Place North',
#               'Park Avenue North',
#               'Phinney Avenue North',
#               'Pontius Avenue North',
#               'Queen Anne Avenue North',
#               'Raymond Street North',
#               'Ridgemont Way North',
#               'Roosevelt Way North',
#               'Roslyn Place North',
#               'Solent Road North',
#               'Spencer Street North',
#               'Stendall Drive North',
#               'Stendall Place North',
#               'Stone Avenue North',
#               'Stone Way North',
#               'Stroud Avenue North',
#               'Sunnyside Avenue North',
#               'Sunset Boulevard North',
#               'Taylor Avenue North',
#               'Taylor Place North',
#               'Terry Avenue North',
#               'Troll Avenue North',
#               'Wallingford Avenue North',
#               'Warren Avenue North',
#               'Washington Avenue North',
#               'Watson Street North',
#               'Waverly Place North',
#               'Wayne Place North',
#               'West Green Lake Drive North',
#               'West Green Lake Way North',
#               'West green lake Drive North',
#               'Westlake Avenue North',
#               'Whitman Avenue North',
#               'Wingard Court North',
#               'Winona Avenue North',
#               'Winslow Place North',
#               'Woodland Park Avenue North',
#               'Woodland Place North',
#               'Woodlawn Avenue North',
#               'Yale Avenue North',
#               'phinney Avenue North',
#               'queen anne Avenue North',
#               'woodland park Avenue North'},
#              'Northeast': {'100th Avenue Northeast',
#               '100th Lane Northeast',
#               '100th Place Northeast',
#               '101st Avenue Northeast',
#               '101st Court Northeast',
#               '101st Lane Northeast',
#               '101st Place Northeast',
#               '101st Way Northeast',
#               '102nd Avenue Northeast',
#               '102nd Court Northeast',
#               '102nd Lane Northeast',
#               '102nd Place Northeast',
#               '102nd Way Northeast',
#               '103rd Avenue Northeast',
#               '103rd Court Northeast',
#               '103rd Lane Northeast',
#               '103rd Place Northeast',
#               '104th Avenue Northeast',
#               '104th Place Northeast',
#               '105th Avenue Northeast',
#               '105th Court Northeast',
#               '105th Place Northeast',
#               '106th Avenue Northeast',
#               '106th Court Northeast',
#               '106th Lane Northeast',
#               '106th Place Northeast',
#               '107th Avenue Northeast',
#               '107th Place Northeast',
#               '108th Avenue Northeast',
#               '108th Court Northeast',
#               '108th Place Northeast',
#               '108th Street Northeast',
#               '109th Avenue Northeast',
#               '109th Court Northeast',
#               '109th Lane Northeast',
#               '109th Place Northeast',
#               '10th Avenue Northeast',
#               '10th Place Northeast',
#               '110th Avenue Northeast',
#               '110th Lane Northeast',
#               '110th Place Northeast',
#               '110th Way Northeast',
#               '111th Avenue Northeast',
#               '111th Court Northeast',
#               '111th Lane Northeast',
#               '111th Place Northeast',
#               '111th Way Northeast',
#               '112th Avenue Northeast',
#               '112th Court Northeast',
#               '112th Drive Northeast',
#               '112th Lane Northeast',
#               '112th Place Northeast',
#               '112th Way Northeast',
#               '113th Avenue Northeast',
#               '113th Court Northeast',
#               '113th Lane Northeast',
#               '113th Place Northeast',
#               '113th Way Northeast',
#               '114th Avenue Northeast',
#               '114th Court Northeast',
#               '114th Drive Northeast',
#               '114th Lane Northeast',
#               '114th Place Northeast',
#               '115th Avenue Northeast',
#               '115th Court Northeast',
#               '115th Lane Northeast',
#               '115th Place Northeast',
#               '116th Avenue Northeast',
#               '116th Court Northeast',
#               '116th Place Northeast',
#               '116th Street Northeast',
#               '116th Way Northeast',
#               '117th Avenue Northeast',
#               '117th Drive Northeast',
#               '117th Place Northeast',
#               '118th Avenue Northeast',
#               '118th Court Northeast',
#               '118th Place Northeast',
#               '119th Avenue Northeast',
#               '119th Place Northeast',
#               '11th Avenue Northeast',
#               '120th Ave Northeast',
#               '120th Avenue Northeast',
#               '120th Court Northeast',
#               '120th Lane Northeast',
#               '120th Place Northeast',
#               '121st Avenue Northeast',
#               '121st Court Northeast',
#               '121st Lane Northeast',
#               '121st Place Northeast',
#               '121st Way Northeast',
#               '122nd Avenue Northeast',
#               '122nd Court Northeast',
#               '122nd Lane Northeast',
#               '122nd Place Northeast',
#               '123rd Avenue Northeast',
#               '123rd Lane Northeast',
#               '124th Avenue Northeast',
#               '124th Court Northeast',
#               '124th Lane Northeast',
#               '124th Place Northeast',
#               '125th Avenue Northeast',
#               '125th Drive Northeast',
#               '125th Lane Northeast',
#               '125th Place Northeast',
#               '125th Way Northeast',
#               '126th Avenue Northeast',
#               '126th Court Northeast',
#               '126th Place Northeast',
#               '126th Way Northeast',
#               '127th Avenue Northeast',
#               '127th Drive Northeast',
#               '127th Lane Northeast',
#               '127th Place Northeast',
#               '128th Avenue Northeast',
#               '128th Lane Northeast',
#               '128th Place Northeast',
#               '128th Way Northeast',
#               '129th Avenue Northeast',
#               '129th Court Northeast',
#               '129th Lane Northeast',
#               '129th Place Northeast',
#               '12th Avenue Northeast',
#               '130th Avenue Northeast',
#               '130th Court Northeast',
#               '130th Lane Northeast',
#               '130th Place Northeast',
#               '131st Avenue Northeast',
#               '131st Court Northeast',
#               '131st Lane Northeast',
#               '131st Place Northeast',
#               '132nd Avenue Northeast',
#               '133rd Avenue Northeast',
#               '133rd Place Northeast',
#               '134th Avenue Northeast',
#               '134th Court Northeast',
#               '135th Avenue Northeast',
#               '136th Avenue Northeast',
#               '136th Court Northeast',
#               '136th Place Northeast',
#               '137th Place Northeast',
#               '139th Avenue Northeast',
#               '139th Place Northeast',
#               '140th Avenue Northeast',
#               '141st Avenue Northeast',
#               '142nd Place Northeast',
#               '146th Avenue Northeast',
#               '147th Place Northeast',
#               '148th Avenue Northeast',
#               '14th Avenue Northeast',
#               '14th Place Northeast',
#               '150th Avenue Northeast',
#               '151st Avenue Northeast',
#               '152nd Avenue Northeast',
#               '152nd Place Northeast',
#               '154th Avenue Northeast',
#               '155th Avenue Northeast',
#               '156th Avenue Northeast',
#               '156th Place Northeast',
#               '157th Avenue Northeast',
#               '157th Place Northeast',
#               '158th Avenue Northeast',
#               '158th Place Northeast',
#               '159th Avenue Northeast',
#               '159th Place Northeast',
#               '15TH Ave Northeast',
#               '15th Ave Northeast',
#               '15th Avenue Northeast',
#               '15th Place Northeast',
#               '160th Avenue Northeast',
#               '160th Place Northeast',
#               '161st Avenue Northeast',
#               '162nd Avenue Northeast',
#               '164th Avenue Northeast',
#               '165th Avenue Northeast',
#               '166th Avenue Northeast',
#               '167th Place Northeast',
#               '168th Avenue Northeast',
#               '168th Street Northeast',
#               '169th Place Northeast',
#               '16th Avenue Northeast',
#               '170th Avenue Northeast',
#               '170th Lane Northeast',
#               '170th Place Northeast',
#               '171st Avenue Northeast',
#               '171st Lane Northeast',
#               '171st Place Northeast',
#               '171st Street Northeast',
#               '172nd Avenue Northeast',
#               '172nd Street Northeast',
#               '173rd Avenue Northeast',
#               '175th Avenue Northeast',
#               '176th Avenue Northeast',
#               '178th Place Northeast',
#               '17th Avenue Northeast',
#               '17th Avenue Northeast;17th Place Northeast',
#               '17th Place Northeast',
#               '180th Avenue Northeast',
#               '185th Avenue Northeast',
#               '18th Avenue Northeast',
#               '19th Avenue Northeast',
#               '1st Avenue Northeast',
#               '208th Avenue Northeast',
#               '20th Avenue Northeast',
#               '20th Place Northeast',
#               '210th Avenue Northeast',
#               '211th Avenue Northeast',
#               '212th Avenue Northeast',
#               '215th Avenue Northeast',
#               '218th Avenue Northeast',
#               '21st Avenue Northeast',
#               '21st Place Northeast',
#               '224th Avenue Northeast',
#               '224th Court Northeast',
#               '224th Place Northeast',
#               '228th Ave Northeast',
#               '228th Avenue Northeast',
#               '228th Way Northeast',
#               '22nd Avenue Northeast',
#               '22nd Place Northeast',
#               '233rd Avenue Northeast',
#               '234th Place Northeast',
#               '235th Avenue Northeast',
#               '236th Avenue Northeast',
#               '23rd Avenue Northeast',
#               '23rd Court Northeast',
#               '23rd Place Northeast',
#               '240th Avenue Northeast',
#               '241st Terrace Northeast',
#               '243rd Place Northeast',
#               '244th Avenue Northeast',
#               '245th Avenue Northeast',
#               '249th Place Northeast',
#               '24th Avenue Northeast',
#               '24th Place Northeast',
#               '256th Avenue Northeast',
#               '25th Avenue Northeast',
#               '25th Place Northeast',
#               '264th Avenue Northeast',
#               '26th Avenue Northeast',
#               '26th Street Northeast',
#               '27th Avenue Northeast',
#               '28th Avenue Northeast',
#               '292nd Avenue Northeast',
#               '29th Avenue Northeast',
#               '2nd Avenue Northeast',
#               '2nd Street Northeast',
#               '30th Avenue Northeast',
#               '318th Avenue Northeast',
#               '31st Avenue Northeast',
#               '31st Place Northeast',
#               '32nd Avenue Northeast',
#               '33rd Avenue Northeast',
#               '33rd Place Northeast',
#               '34th Avenue Northeast',
#               '35th Avenue Northeast',
#               '36th Avenue Northeast',
#               '37th Avenue Northeast',
#               '38th Avenue Northeast',
#               '39th Avenue Northeast',
#               '3rd Avenue Northeast',
#               '40th Avenue Northeast',
#               '41st Avenue Northeast',
#               '41st Place Northeast',
#               '42nd Avenue Northeast',
#               '42nd Place Northeast',
#               '43rd Avenue Northeast',
#               '43rd Place Northeast',
#               '44th Avenue Northeast',
#               '44th Place Northeast',
#               '45th Avenue Northeast',
#               '46th Avenue Northeast',
#               '46th Place Northeast',
#               '47th Avenue Northeast',
#               '47th Place Northeast',
#               '48th Avenue Northeast',
#               '48th Place Northeast',
#               '49th Avenue Northeast',
#               '4th Avenue Northeast',
#               '4th Street Northeast',
#               '50th Avenue Northeast',
#               '51st Avenue Northeast',
#               '52nd Avenue Northeast',
#               '53rd Avenue Northeast',
#               '53rd Court Northeast',
#               '54th Avenue Northeast',
#               '55th Avenue Northeast',
#               '55th Place Northeast',
#               '56th Avenue Northeast',
#               '56th Place Northeast',
#               '57th Avenue Northeast',
#               '57th Place Northeast',
#               '58th Avenue Northeast',
#               '59th Avenue Northeast',
#               '5th Avenue Northeast',
#               '60th Avenue Northeast',
#               '61st Avenue Northeast',
#               '62nd Avenue Northeast',
#               '63rd Avenue Northeast',
#               '64th Avenue Northeast',
#               '64th Court Northeast',
#               '64th Place Northeast',
#               '64th Street Northeast',
#               '64th Terrace Northeast',
#               '65th Avenue Northeast',
#               '65th Place Northeast',
#               '66th Place Northeast',
#               '67th Avenue Northeast',
#               '67th Lane Northeast',
#               '68th Avenue Northeast',
#               '68th Place Northeast',
#               '69th Avenue Northeast',
#               '6th Avenue Northeast',
#               '6th Place Northeast',
#               '70th Avenue Northeast',
#               '70th Lane Northeast',
#               '70th Place Northeast',
#               '71st Avenue Northeast',
#               '71st Place Northeast',
#               '72nd Avenue Northeast',
#               '72nd Place Northeast',
#               '73rd Avenue Northeast',
#               '73rd Place Northeast',
#               '74th Avenue Northeast',
#               '74th Court Northeast',
#               '74th Place Northeast',
#               '75th Avenue Northeast',
#               '76th Avenue Northeast',
#               '76th Court Northeast',
#               '76th Place Northeast',
#               '77th Avenue Northeast',
#               '78th Lane Northeast',
#               '78th Place Northeast',
#               '79th Avenue Northeast',
#               '79th Court Northeast',
#               '79th Place Northeast',
#               '79th Way Northeast',
#               '7th Avenue Northeast',
#               '80th Avenue Northeast',
#               '80th Place Northeast',
#               '81st Avenue Northeast',
#               '81st Court Northeast',
#               '81st Place Northeast',
#               '82nd Avenue Northeast',
#               '82nd Place Northeast',
#               '83rd Avenue Northeast',
#               '83rd Court Northeast',
#               '83rd Lane Northeast',
#               '83rd Place Northeast',
#               '84th Avenue Northeast',
#               '84th Court Northeast',
#               '84th Place Northeast',
#               '84th Street Northeast',
#               '85th Avenue Northeast',
#               '85th Place Northeast',
#               '86th Avenue Northeast',
#               '86th Place Northeast',
#               '87th Avenue Northeast',
#               '87th Court Northeast',
#               '87th Place Northeast',
#               '88th Avenue Northeast',
#               '88th Court Northeast',
#               '88th Place Northeast',
#               '88th Street Northeast',
#               '89th Avenue Northeast',
#               '89th Court Northeast',
#               '89th Place Northeast',
#               '8th Avenue Northeast',
#               '8th Court Northeast',
#               '8th Street Northeast',
#               '90th Avenue Northeast',
#               '90th Court Northeast',
#               '90th Place Northeast',
#               '91st Avenue Northeast',
#               '91st Court Northeast',
#               '91st Lane Northeast',
#               '91st Place Northeast',
#               '92nd Avenue Northeast',
#               '92nd Place Northeast',
#               '93rd Avenue Northeast',
#               '93rd Court Northeast',
#               '93rd Lane Northeast',
#               '93rd Place Northeast',
#               '94th Avenue Northeast',
#               '94th Place Northeast',
#               '95th Avenue Northeast',
#               '95th Place Northeast',
#               '96th Avenue Northeast',
#               '96th Place Northeast',
#               '97th Avenue Northeast',
#               '97th Lane Northeast',
#               '97th Place Northeast',
#               '98th Avenue Northeast',
#               '98th Place Northeast',
#               '99th Avenue Northeast',
#               '99th Place Northeast',
#               '9th Avenue Northeast',
#               'A Street Northeast',
#               'Adams Lane Northeast',
#               'Alton Avenue Northeast',
#               'Alton Place Northeast',
#               'Ann Arbor Avenue Northeast',
#               'Apple Jack Lane Northeast',
#               'Arklow Place Northeast',
#               'Asotin Place Northeast',
#               'Augusta Avenue Northeast',
#               'Avondale Road Northeast',
#               'Ballinger Way Northeast',
#               'Banner Way Northeast',
#               'Bannister Street Northeast',
#               'Barber Cut Off Road Northeast',
#               'Barrett Road Northeast',
#               'Bartlett Avenue Northeast',
#               'Beach Drive Northeast',
#               'Bear Creek Road Northeast',
#               'Bellevue Way Northeast',
#               'Benton Lane Northeast',
#               'Boston Harbor Road Northeast',
#               'Bothell Way Northeast',
# ...
#               '75th Ave W',
#               'Bridgeport Way W',
#               'Cirque Dr W',
#               'Custer Road W',
#               'Grandview Dr W',
#               'Lakewood Drive W',
#               'Mildred Street W'},
#              'W.': {'Rochester St. W.'},
#              'WA': {'17625 140th Ave SE, Renton, WA'},
#              'WA-99': {'WA-99'},
#              'WY': {'NE 62nd WY', 'NE 63rd WY'},
#              'Walk': {'Mina Walk'},
#              'Wall': {'South Wall'},
#              'Walter': {'Walter'},
#              'Warren': {'Warren'},
#              'Waugh': {'Waugh'},
#              'Way': {'1135 NW Leary Way',
#               '1205 Port Gardner Way',
#               '12412 SE Newcastle Way',
#               'Admiral Way',
#               'Alaskan Way',
#               'Amethyst Way',
#               'Ash Way',
#               'Autumn Way',
#               'Battery Way',
#               'Bernie Whitebear Way',
#               'Buck Way',
#               'Buckhorn Way',
#               'Cains Way',
#               'Cameron Way',
#               'Central Way',
#               'Chatterton Way',
#               'Christie Way',
#               'College Way',
#               'Columbine Way',
#               'Country Club Way',
#               'Craftsman Way',
#               'Craigo Park Way',
#               'Denny Way',
#               'Drummond Way',
#               'E Mercer Way',
#               'East College Way',
#               'East Denny Way',
#               'East James Way',
#               'East Morley Way',
#               'East North Bend Way',
#               'East Olive Way',
#               'East Saint Andrews Way',
#               'East Sims Way',
#               'East Sunset Way',
#               'East Yesler Way',
#               'Edmonds Way',
#               'El Capitan Way',
#               'Evergreen Way',
#               'Fashion Way',
#               'Galaxy Way',
#               'Galey Way',
#               'Glen Forest Way',
#               'Goldeneye Way',
#               'Harrier Way',
#               'Higgins Airport Way',
#               'Hillcrest Park Way',
#               'Jay Way',
#               'Kirkland Way',
#               'Kitsap Way',
#               'Kiwanis Way',
#               'Lake Ballinger Way',
#               'Lakepoint Way',
#               'Lambrick Way',
#               'Larrabee Way',
#               'Leigh Way',
#               'Lord Nelson Way',
#               'Martin Luther King Jr Way',
#               'Martin Luther King Jr. Way',
#               'Martin Luther King Junior Way',
#               'McMorran Way',
#               'Milton Way',
#               'Misty Way',
#               'N Bend Way',
#               'N Captiol Way',
#               'N. Northlake Way',
#               'NE 103rd Way',
#               'NE 110th Way',
#               'NE 63rd Way',
#               'NE Bothell Way',
#               'NE Northgate Way',
#               'NE Waaga Way',
#               'NW Randall Way',
#               'Newcastle Way',
#               'Newport Way',
#               'North Clogston Way',
#               'North Landing Way',
#               'North Mercer Way',
#               'North Northgate Way',
#               'North Northlake Way',
#               'North Phinney Way',
#               'Northeast 104th Way',
#               'Northeast 109th Way',
#               'Northeast 115th Way',
#               'Northeast 119th Way',
#               'Northeast 122nd Way',
#               'Northeast 125th Way',
#               'Northeast 128th Way',
#               'Northeast 130th Way',
#               'Northeast 131st Way',
#               'Northeast 141st Way',
#               'Northeast 142nd Way',
#               'Northeast 144th Way',
#               'Northeast 42nd Way',
#               'Northeast 58th Way',
#               'Northeast 80th Way',
#               'Northeast 86th Way',
#               'Northeast 94th Way',
#               'Northeast 95th Way',
#               'Northeast 98th Way',
#               'Northeast 99th Way',
#               'Northeast Bothell Way',
#               'Northeast Emerald Way',
#               'Northeast Leary Way',
#               'Northeast Northgate Way',
#               'Northeast Northlake Way',
#               'Northeast Princeton Way',
#               'Northeast Redmond Way',
#               'Northeast Totem Lake Way',
#               'Northridge Way',
#               'Northrup Way',
#               'Northup Way',
#               'Northwest Ballard Way',
#               'Northwest Greenbrier Way',
#               'Northwest Leary Way',
#               'Northwest Lindvig Way',
#               'Northwest Milford Way',
#               'Northwest Norcross Way',
#               'Northwest Olhava Way',
#               'Northwest Olympic College Way',
#               'Northwest Woodbine Way',
#               'Olive Way',
#               'Outlet Collection Way',
#               'Parker Way',
#               'Paskin Way',
#               'Passage Way',
#               'Pattison Way',
#               'Pegasus Way',
#               'Pinnacle Way',
#               'Pioneer Way',
#               'Pomona Way',
#               'Poplar Way',
#               'Preston Way',
#               'Prospector Way',
#               'Ramsay Way',
#               'Ravine Way',
#               'Redmond Way',
#               'Ridge Way',
#               'Rogers Way',
#               'Ruston Way',
#               'S Grady Way',
#               'S Tacoma Way',
#               'SE Everett Mall Way',
#               'SW Grady Way',
#               'Salsbury Way',
#               'Sanderling Way',
#               'Sea Lion Way',
#               'Seahawks Way',
#               'Secretariat Way',
#               'Serene Way',
#               'Shore Way',
#               'Silverstone Way',
#               'Sinclair Way',
#               'Skogstad Way',
#               'South Columbian Way',
#               'South Conover Way',
#               'South Grady Way',
#               'South Industrial Way',
#               'South Royal Brougham Way',
#               'South Ryan Way',
#               'South Tacoma Way',
#               'South royal brougham Way',
#               'Southeast 69th Way',
#               'Southeast 96th Way',
#               'Southeast Eastgate Way',
#               'Southeast Everett Mall Way',
#               'Southeast High Point Way',
#               'Southeast North Bend Way',
#               'Southwest Admiral Way',
#               'Southwest Avalon Way',
#               'Southwest Everett Mall Way',
#               'Southwest Grady Way',
#               'Southwest Heinze Way',
#               'Southwest Hemlock Way',
#               'Southwest Klickitat Way',
#               'Southwest Maple Way',
#               'Spruce Way',
#               'Stevens Way',
#               'Stonebridge Way',
#               'Stormtide Way',
#               'Sunnymead Way',
#               'Sunriver Way',
#               'Supermall Way',
#               'Tiffany Way',
#               'Valley Mall Way',
#               'Van Isle Way',
#               'Ventura Way',
#               'Watkiss Way',
#               'Waverly Park Way',
#               'Waverly Way',
#               'West Armory Way',
#               'West College Way',
#               'West Commodore Way',
#               'West Denny Way',
#               'West Government Way',
#               'West North Bend Way',
#               'West Roberts Way',
#               'West Rose Nye Way',
#               'West Sims Way',
#               'West Sunset Way',
#               'Wheaton Way',
#               'Wild Ridge Way',
#               'Wilhelmina Way',
#               'Williams Way',
#               'Willowpark Way',
#               'Wisterwood Way',
#               'Yesler Way'},
#              'West': {'100th Avenue West',
#               '10th Avenue West',
#               '10th Place West',
#               '10th Street West',
#               '11th Avenue West',
#               '12th Avenue West',
#               '13th Avenue West',
#               '14th Avenue West',
#               '14th Place West',
#               '15th Avenue West',
#               '15th Place West',
#               '16th Avenue West',
#               '17th Avenue West',
#               '18th Avenue West',
#               '19th Lane West',
#               '1st Avenue West',
#               '20th Avenue West',
#               '20th Place West',
#               '21st Avenue West',
#               '22nd Avenue West',
#               '23rd Avenue West',
#               '24th Avenue West',
#               '24th Place West',
#               '25th Avenue West',
#               '25th Place West',
#               '26th Avenue West',
#               '26th Place West',
#               '27th Avenue West',
#               '27th Place West',
#               '28th Avenue West',
#               '28th Place West',
#               '29th Avenue West',
#               '2nd Avenue West',
#               '2nd Street West',
#               '30th Avenue West',
#               '31st Avenue West',
#               '32nd Avenue West',
#               '33rd Avenue West',
#               '34th Avenue West',
#               '34th Court West',
#               '35th Avenue West',
#               '36th Avenue West',
#               '37th Avenue West',
#               '38th Avenue West',
#               '39th Avenue West',
#               '3rd Avenue West',
#               '3rd Street West',
#               '40th Avenue West',
#               '41st Avenue West',
#               '42MD Ave South West',
#               '42nd Avenue West',
#               '43rd Avenue West',
#               '44th Avenue West',
#               '44th Street West',
#               '45th Avenue West',
#               '46th Avenue West',
#               '47th Place West',
#               '4th Avenue West',
#               '4th Street West',
#               '51st Avenue Court West',
#               '51st Street West',
#               '52nd Avenue West',
#               '53rd Avenue West',
#               '54th Avenue Court West',
#               '54th Street West',
#               '58th Street Court West',
#               '5th Avenue West',
#               '5th Street West',
#               '60th Street West',
#               '61st Avenue West',
#               '67th Avenue West',
#               '6th Avenue West',
#               '6th Street West',
#               '72nd Avenue Court West',
#               '73rd Avenue Court West',
#               '76th Avenue West',
#               '78th Place West',
#               '7th Avenue West',
#               '7th Street West',
#               '80th Avenue West',
#               '82nd Avenue West',
#               '84th Avenue West',
#               '86th Avenue West',
#               '8th Avenue West',
#               '8th Place West',
#               '8th Street West',
#               '9th Avenue West',
#               '9th Street West',
#               'Alameda Avenue West',
#               'Alaskan Way West',
#               'Altavista Place West',
#               'Amgen Court West',
#               'Amherst Place West',
#               'Andover Park West',
#               'Arapahoe Place West',
#               'Binghampton Street West',
#               'Bishop Place West',
#               'Briarcliff Lane West',
#               'Bridgeport Way West',
#               'Brygger Drive West',
#               'Bukin Drive West',
#               'Burnside Road West',
#               'Burton Place West',
#               'Center Street West',
#               'Chambers Creek Road West',
#               'Cirque Drive West',
#               'Clise Place West',
#               'Condon Way West',
#               'Conkling Place West',
#               'Constance Drive West',
#               'Crane Drive West',
#               'Crestmont Place West',
#               'Croft Avenue West',
#               'Dartmouth Avenue West',
#               'Duke Road West',
#               'Eastmont Way West',
#               'Edgemont Place West',
#               'Elliott Avenue West',
#               'Eyres Place West',
#               'Garthland Place West',
#               'Gay Avenue West',
#               'Gilman Avenue West',
#               'Gilman Drive West',
#               'Gilman Place West',
#               'Gorge Road West',
#               'Grant Road West',
#               'Highway 101 West',
#               'Humes Place West',
#               'Lake Avenue West',
#               'Lawton Lane West',
#               'Logan Avenue West',
#               'Lohbrunner Road West',
#               'MacDonald Drive West',
#               'Maddock Avenue West',
#               'Magnolia Boulevard West',
#               'Magnolia Lane West',
#               'Magnolia Way West',
#               'Meadow Blvd West',
#               'Memory Lane West',
#               'Montavista Place West',
#               'Montvale Court West',
#               'Montvale Place West',
#               'Morley Place West',
#               'Northeast Day Road West',
#               'Olympic Way West',
#               'Patten Place West',
#               'Perkins Lane West',
#               'Piedmont Place West',
#               'Prosch Avenue West',
#               'Railroad Avenue West',
#               'Rosemont Place West',
#               'Shilshole Avenue North West',
#               'Sound View Drive West',
#               'Sunset Drive West',
#               'Texas Way West',
#               'Thorndyke Avenue West',
#               'Thorndyke Place West',
#               'Treebank Road West',
#               'Van Buren Avenue West',
#               'Viaduct Avenue West',
#               'Viewmont Way West',
#               'Washington Avenue West',
#               'West Viewmont Way West',
#               'Western Avenue West',
#               'Westmont Way West',
#               'Westview Drive West',
#               'Whalley Place West',
#               'Willard Avenue West',
#               'Williams Avenue West',
#               'Winslow Way West',
#               'Wolfe Place West',
#               'van buren Avenue West',
#               'west point Avenue West'},
#              'Wood': {'St. Francis Wood'},
#              'Woods': {'Mysty Woods', 'University Woods'},
#              'Wy': {'East College Wy'},
#              'Yesler': {'Yesler'},
#              'av.': {'Pacific av.'},
#              'ave': {'111th ave', 'south puget sound ave'},
#              'avenue': {'6th avenue',
#               'Ericksen avenue',
#               'south mason avenue',
#               'south puget sound avenue'},
#              'bjuin': {'bjuin'},
#              'boulevard': {'tacoma mall boulevard'},
#              'driveway': {'West queen anne driveway'},
#              'http://local.safeway.com/wa/tacoma-1594.html': {'http://local.safeway.com/wa/tacoma-1594.html'},
#              'm': {'m'},
#              'n': {'10415 Greenwood Ave n'},
#              'r': {'r'},
#              'se': {'25th ave se'},
#              'south': {'park avenue south'},
#              'southeast': {'103rd Avenue southeast'},
#              'southwest': {'82nd street southwest', 'phillips road southwest'},
#              'st': {'1017 S boone st',
#               'E 11th st',
#               'NE 20th st',
#               'NE 90th st',
#               'S I st'},
#              'street': {'NE 45th street',
#               'West 4th street',
#               'south 12th street',
#               'south 54th street',
#               'south 56th street',
#               'south 58th street',
#               'south 60th street',
#               'south 66th street',
#               'south 74th street',
#               'south clement street',
#               'south gove street',
#               'south hosmer street',
#               'south lawrence street',
#               'south monroe street',
#               'south orchard street',
#               'south pine street',
#               'south stevens street',
#               'south warner street'},
#              'wa': {'144th pl ne bellevue wa'},
#              'west': {'32nd Place west',
#               '40th street west',
#               '46th street court west',
#               '4th street west',
#               '52nd street court west',
#               '54th avenue court west',
#               '60th street west',
#               '70h avenue court west',
#               '74th street west',
#               '75th avenue court west',
#               '82nd avenue west',
#               '83rd avenue court west',
#               '86th avenue west',
#               '87th avenue court west',
#               'alameda avenue west',
#               'sunset drive west'}})
